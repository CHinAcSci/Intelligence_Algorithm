# %%
## GA
from GA import GeneticTSP
# 创建求解器实例
tsp_solver = GeneticTSP(num_cities=10, pop_size=100, generations=1000)

# 求解TSP
best_path, best_distance = tsp_solver.solve()

# 绘制结果
tsp_solver.plot_route()
# Out:
# Generation 0: Best distance = 1110.20
# Generation 100: Best distance = 567.74
# Generation 200: Best distance = 550.08
# Generation 300: Best distance = 549.51
# Generation 400: Best distance = 549.51
# Generation 500: Best distance = 505.89
# Generation 600: Best distance = 505.89
# Generation 700: Best distance = 505.89
# Generation 800: Best distance = 498.20
# Generation 900: Best distance = 494.83
#
# Final Results:
# Best distance found: 494.83
# Time taken: 14.04 seconds
